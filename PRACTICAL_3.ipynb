# %% [markdown]
# <a href="https://colab.research.google.com/github/sarveshkuvalekar/DSBDA_LAB_Practicals/blob/main/PRACTICAL_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
d1 = pd.DataFrame({'RN':[1,2,3,4,5], 'SName':['Nishant','Sarvesh','Soham','Shubham','Aditya']})
d2 = pd.DataFrame({'RN':[1,2,3,4,5], 'Marks':['23','59','100','89','78']})
pd.merge(d1,d2,on='RN')
# Out:
#    RN    SName Marks
# 0   1  Nishant    23
# 1   2  Sarvesh    59
# 2   3    Soham   100
# 3   4  Shubham    89
# 4   5   Aditya    78

# %%
df = pd.DataFrame({'RN':[1,2,3,4,5], 'name':['Nishant','Sarvesh','Soham','Shubham','Aditya'], 'Marks':['23','59','100','89','78']})
df.pivot(index='RN', columns='name', values='Marks')
# Out:
# name Aditya Nishant Sarvesh Shubham Soham
# RN
# 1       NaN      23     NaN     NaN   NaN
# 2       NaN     NaN      59     NaN   NaN
# 3       NaN     NaN     NaN     NaN   100
# 4       NaN     NaN     NaN      89   NaN
# 5        78     NaN     NaN     NaN   NaN

# %%
df=pd.DataFrame({'RN':[1,2,None,4,None], 'name':['Nishant','Sarvesh','Soham','Shubham','Aditya'], 'Marks': ['23','59','100','89','78']})
df.pivot(index='RN', columns='name', values='Marks')
df
# Out:
#     RN     name Marks
# 0  1.0  Nishant    23
# 1  2.0  Sarvesh    59
# 2  NaN    Soham   100
# 3  4.0  Shubham    89
# 4  NaN   Aditya    78

# %%
df.backfill(axis=0)
# Out:
# <ipython-input-8-6b25eac61092>:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   df.backfill(axis=0)
#     RN     name Marks
# 0  1.0  Nishant    23
# 1  2.0  Sarvesh    59
# 2  4.0    Soham   100
# 3  4.0  Shubham    89
# 4  NaN   Aditya    78

# %%
df.backfill(axis=1)
# Out:
# <ipython-input-9-f49a54d1095d>:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   df.backfill(axis=1)
#        RN     name Marks
# 0     1.0  Nishant    23
# 1     2.0  Sarvesh    59
# 2   Soham    Soham   100
# 3     4.0  Shubham    89
# 4  Aditya   Aditya    78

# %%
data=pd.read_excel('/content/Demo Data DSBDA.xlsx')
data
# Out:
#           Sr. no.                    Roll No        Name of the Student   DM  \
# 0               1                     SCOA01              ALISHA SHEIKH   24
# 1               2                     SCOA02  SOHAM JAYYANNTH DESHMUKKH   16
# 2               3                     SCOA03         SHELAR NEHA NILESH   20
# 3               4                     SCOA04                RIYA JAWALE   18
# 4               5                     SCOA05      NARHE VARSHA RAOSAHEB   20
# ..            ...                        ...                        ...  ...
# 77  Maximum marks                        NaN                        NaN   24
# 78            NaN                        NaN                        NaN  NaN
# 79            NaN                        NaN                        NaN  NaN
# 80            NaN                        NaN                        NaN  NaN
# 81            NaN  Internal Exam Coordinator                        NaN  NaN
#
# ...

# %%
genders = ['Male', 'Female']
data['Gender'] = np.random.choice(genders, size=len(data))
data
# Out:
#           Sr. no.                    Roll No        Name of the Student   DM  \
# 0               1                     SCOA01              ALISHA SHEIKH   24
# 1               2                     SCOA02  SOHAM JAYYANNTH DESHMUKKH   16
# 2               3                     SCOA03         SHELAR NEHA NILESH   20
# 3               4                     SCOA04                RIYA JAWALE   18
# 4               5                     SCOA05      NARHE VARSHA RAOSAHEB   20
# ..            ...                        ...                        ...  ...
# 77  Maximum marks                        NaN                        NaN   24
# 78            NaN                        NaN                        NaN  NaN
# 79            NaN                        NaN                        NaN  NaN
# 80            NaN                        NaN                        NaN  NaN
# 81            NaN  Internal Exam Coordinator                        NaN  NaN
#
# ...

# %%
d = data.groupby('Gender')
d.first()
# Out:
#        Sr. no.  Roll No        Name of the Student  DM FDS OOP  CG DELD  \
# Gender
# Female       1   SCOA01              ALISHA SHEIKH  24  27  20  15   16
# Male         2   SCOA02  SOHAM JAYYANNTH DESHMUKKH  16   9   9  AB   AB
#
#         Unnamed: 8  Unnamed: 9  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# Gender                          ...
# Female         NaN         NaN  ...          NaN          NaN          NaN
# Male           NaN         NaN  ...          NaN          NaN          NaN
#
#         Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# Gender
# Female          NaN          NaN          NaN          NaN          NaN
# Male            NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 22  Unnamed: 23
# Gender
# Female          NaN         None
# Male            NaN         321`
#
# [2 rows x 24 columns]

# %%
d.count()
# Out:
#         Sr. no.   Roll No  Name of the Student  DM  FDS  OOP  CG  DELD  \
# Gender
# Female       41        37                   36  41   41   41  42    41
# Male         35        31                   31  35   35   35  35    35
#
#         Unnamed: 8  Unnamed: 9  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# Gender                          ...
# Female           0           0  ...            0            0            0
# Male             0           0  ...            0            0            0
#
#         Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# Gender
# Female            0            0            0            0            0
# Male              0            0            0            0            0
#
#         Unnamed: 22  Unnamed: 23
# Gender
# Female            0            0
# Male              0            2
#
# [2 rows x 24 columns]

# %%
d.size()
# Out:
# Gender
# Female    42
# Male      40
# dtype: int64

# %%
print(d.get_group('Male'))
# Out:
#                         Sr. no.  Roll No          Name of the Student   DM  \
# 1                             2   SCOA02    SOHAM JAYYANNTH DESHMUKKH   16
# 4                             5   SCOA05        NARHE VARSHA RAOSAHEB   20
# 5                             6   SCOA06      BHUTDA MAHESH SHANTILAL   20
# 7                             8   SCOA08    DESHPANDE SRUSHTI VINAYAK   24
# 9                            10   SCOA10           ERANDE TEJAS DIPAK   24
# 10                           11   SCOA11        TRIPATHI VIKALP VIKAS   18
# 16                           17   SCOA17      KHATAL NANDINI RAJENDRA   12
# 18                           19   SCOA19  CHINCHANE SANSKRUTI GAJANAN   22
# 21                           22   SCOA22         PAWAR DNYANESHWARI V   21
# 22                           23   SCOA23      POTDAR PRANAV SURYAKANT   18
# 24                           25   SCOA25                 HEMANT SAINI   22
# ...

# %%
data['DM'].corr(data['DELD'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-47f72dd562f8> in <cell line: 0>()
# ----> 1 data['DM'].corr(data['DELD'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2971             return np.nan
#    2972
# -> 2973         this_values = this.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2974         other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2975
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in to_numpy(self, dtype, copy, na_value, **kwargs)
#     660             values[np.asanyarray(isna(self))] = na_value
#     661
# --> 662         result = np.asarray(values, dtype=dtype)
#     663
#     664         if (copy and not fillna) or (not copy and using_copy_on_write()):
#
# ValueError: could not convert string to float: 'AB'

# %%
print(data['DM'].unique())
print(data['DELD'].unique())
# Out:
# [24 16 20 18 22 12 21 8 14 23 'AB' 6 10 0 2 4 1 nan 'SS' 3 64 50 78.125
#  15.984375]
# [16 'AB' 15 20 7 23 10 13 17 14 22 5 8 6 2 0 27 18 21 9 1 3 nan 'CRJ' 44
#  47.72727273 11.84090909]

# %%
data['DM'] = pd.to_numeric(data['DM'], errors='coerce')
data['DELD'] = pd.to_numeric(data['DELD'], errors='coerce')
data = data.dropna(subset=['DM', 'DELD'])

# %%
data['DM'] = data['DM'].replace('AB', 0)
data['DM'] = pd.to_numeric(data['DM'])
# Do the same for 'DELD' if needed
# Out:
# <ipython-input-29-2f138fa0e6ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DM'] = data['DM'].replace('AB', 0)
# <ipython-input-29-2f138fa0e6ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DM'] = pd.to_numeric(data['DM'])

# %%
data['DM'].corr(data['DELD'])
# Out:
# 0.786340702410276

# %%
data = data.iloc[:67]
data
# Out:
#                           Sr. no.  Roll No          Name of the Student  \
# 0                               1   SCOA01                ALISHA SHEIKH
# 2                               3   SCOA03           SHELAR NEHA NILESH
# 3                               4   SCOA04                  RIYA JAWALE
# 4                               5   SCOA05        NARHE VARSHA RAOSAHEB
# 6                               7   SCOA07         JAGTAP HARISH YUVRAJ
# 7                               8   SCOA08    DESHPANDE SRUSHTI VINAYAK
# 8                               9   SCOA09         DARWEY RUDRA GUNWANT
# 10                             11   SCOA11        TRIPATHI VIKALP VIKAS
# 13                             14   SCOA14            GOYAL SURAJ MANOJ
# 14                             15   SCOA15         DHAWNE DEVANG GANESH
# 15                             16   SCOA16         SHELKE GAURAV GIRISH
# 17                             18   SCOA18      BHUJBAL SRUSHTI VINAYAK
# ...

# %%
new_data = data[['Sr. no.', 'DM','FDS','OOP','CG','DELD']]
new_data
# Out:
#                           Sr. no.         DM        FDS        OOP         CG  \
# 0                               1  24.000000         27         20         15
# 2                               3  20.000000         23         16         15
# 3                               4  18.000000         14         11          8
# 4                               5  20.000000         24         16         24
# 6                               7  22.000000         18          3         16
# 7                               8  24.000000         20         19         16
# 8                               9  22.000000         12          9         15
# 10                             11  18.000000         13          7         18
# 13                             14  16.000000         19          9         13
# 14                             15  18.000000         21         12         12
# 15                             16  20.000000         19         12          9
# ...

# %%
new_data = new_data.apply(pd.to_numeric, errors='coerce')
new_data.dtypes
# Out:
# Sr. no.    float64
# DM         float64
# FDS        float64
# OOP        float64
# CG         float64
# DELD       float64
# dtype: object

# %%
print(new_data.corr())
# Out:
#           Sr. no.        DM       FDS       OOP        CG      DELD
# Sr. no.  1.000000 -0.619369 -0.243253 -0.208540 -0.422266 -0.274436
# DM      -0.619369  1.000000  0.906122  0.845343  0.861297  0.786341
# FDS     -0.243253  0.906122  1.000000  0.766088  0.825933  0.697022
# OOP     -0.208540  0.845343  0.766088  1.000000  0.877653  0.873705
# CG      -0.422266  0.861297  0.825933  0.877653  1.000000  0.815955
# DELD    -0.274436  0.786341  0.697022  0.873705  0.815955  1.000000

# %%
new_data.describe()
# Out:
#          Sr. no.         DM        FDS        OOP         CG       DELD
# count  44.000000  52.000000  52.000000  51.000000  52.000000  52.000000
# mean   31.568182  18.790565  20.439528  14.188042  15.962759  13.818619
# std    18.299063  13.220289  14.514305  11.500923  11.683557   9.743253
# min     1.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    17.500000  12.000000  14.750000   7.000000   8.000000   7.000000
# 50%    31.000000  18.000000  18.500000  12.000000  13.753968  13.000000
# 75%    46.500000  22.000000  23.000000  19.000000  20.000000  20.000000
# max    65.000000  78.125000  89.393939  61.000000  63.000000  47.727273
